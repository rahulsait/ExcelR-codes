# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulsait/ExcelR-codes/blob/main/K_MEANS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import K-Means Clustering Lib :

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
uni = pd.read_csv("/content/Universities.csv")

# %%
uni.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
# Normalization Function :

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_uni_df = scaler.fit_transform(uni.iloc[:,1:])

# %%
# Finding the optimum value of Clusters (K value) :

wcss = [] # wcss : withing cluster sum of squares
for i in range (1,11) :
  kmeans = KMeans(n_clusters = i, random_state = 0)
  kmeans.fit(scaled_uni_df)
  wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# **from the Elbow Method graph we can infer that from K = 4 there is no much movement in the Y axis**
#
# **So optimum K value is in the range(4,6)**

# %%
# Let K = 4
# Building Cluster Algorithm :

from sklearn.cluster import KMeans
clusters_new = KMeans(4, random_state = 42) # using random_state : keeps the partitions consistent for all the iterations
clusters_new.fit(scaled_uni_df)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
clusters_new.labels_
# Out:
# array([2, 3, 0, 2, 0, 2, 2, 0, 2, 3, 2, 0, 0, 1, 2, 1, 2, 1, 0, 0, 0, 0,
#        0, 1, 2], dtype=int32)

# %%
# Assign clusters to the dataset :

uni["clusterid_new"] = clusters_new.labels_

# %%
uni
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
# these are standardized values :

clusters_new.cluster_centers_
# Out:
# array([[-0.12658888,  0.06407139,  0.2224667 ,  0.04516743, -0.38064332,
#          0.02028221],
#        [-1.93029211, -1.98148647,  1.59348244,  1.63857398, -1.23359906,
#         -1.68680366],
#        [ 0.80273428,  0.68086062, -0.90136381, -0.43159988,  0.44062556,
#          0.79526289],
#        [ 0.88122441,  0.5787432 , -0.24316128, -1.56078563,  2.38759968,
#         -0.3064867 ]])

# %%
uni.groupby("clusterid_new").agg(["mean"]).reset_index() # Cluster Profiling
# Out:
#   clusterid_new          SAT      Top10     Accept SFRatio      Expenses  \
#                         mean       mean       mean    mean          mean
# 0             0  1253.000000  77.700000  43.500000   12.90  22008.200000
# 1             1  1061.500000  38.750000  70.000000   19.25   9953.000000
# 2             2  1351.666667  89.444444  21.777778   11.00  33615.555556
# 3             3  1360.000000  87.500000  34.500000    6.50  61133.000000
#
#     GradRate
#         mean
# 0  86.900000
# 1  71.750000
# 2  93.777778
# 3  84.000000

# %%
uni
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...
